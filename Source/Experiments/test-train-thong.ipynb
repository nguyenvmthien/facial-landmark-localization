# %%
# %%capture
# !pip install huggingface_hub[cli] transformers[torch] datasets

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
GH_TOKEN = user_secrets.get_secret("GH_TOKEN")
GH_USERN = user_secrets.get_secret("GH_USERNAME")
HF_TOKEN = user_secrets.get_secret("HF_TOKEN")

# %%
from huggingface_hub import login
login(HF_TOKEN)

# %%
# !rm -rf facial-landmark-localization
# !git clone https://{GH_USERN}:{GH_TOKEN}@github.com/nguyenvmthien/facial-landmark-localization.git
# !cd facial-landmark-localization && git checkout vmphat --force
# Out:
# Cloning into 'facial-landmark-localization'...
# remote: Enumerating objects: 292, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 292 (delta 60), reused 75 (delta 33), pack-reused 188 (from 1)
# Receiving objects: 100% (292/292), 80.75 MiB | 46.45 MiB/s, done.
# Resolving deltas: 100% (118/118), done.
# Branch 'vmphat' set up to track remote branch 'vmphat' from 'origin'.
# Switched to a new branch 'vmphat'

# %%
# !rm -rf /kaggle/working/facial-landmark-localization/Source/saves

# %%
# !wget https://huggingface.co/kartiknarayan/facexformer/resolve/main/ckpts/model.pt 
# !mv model.pt /kaggle/working/facial-landmark-localization/Source

# %%
# %%writefile facial-landmark-localization/Source/train.py
import os
import torch
import torchvision
import datasets
import PIL.Image
from datetime import datetime
from dataclasses import dataclass
from network import FaceXFormer
from transformers import Trainer, TrainingArguments
from torchvision.transforms import InterpolationMode

device = "cuda:0"
dtype = torch.float32
batch_size = 24
gradient_accumulation = 2


def load_model(weight_path):
    model = FaceXFormer().to(device)
    if weight_path:
        checkpoint = torch.load(weight_path, map_location=device)
        model.load_state_dict(checkpoint["state_dict_backbone"])
        print("Loaded pretrained model")
    model = model.to(dtype=dtype)
    return model


def load_dataset(dataset_path):
    dataset = datasets.load_dataset("json", data_files=dataset_path, split="train")
    # dataset = dataset.cast_column("img", datasets.Image())
    dataset = dataset.train_test_split(0.2, shuffle=True, seed=42)
    return dataset


@dataclass
class DataCollator:
    image_base_path: str
    return_tensors: str = "pt"

    transforms_image = torchvision.transforms.Compose(
        [
            torchvision.transforms.Resize(
                size=(224, 224), interpolation=InterpolationMode.BICUBIC
            ),
            torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize(
                mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]
            ),
        ]
    )

    def __call__(self, features: list[dict], return_tensors=None):
        batch = {
            "labels": [],
            "x": [],
            # "tasks": torch.ones(len(features)),
        }

        for feature in features:
            image = PIL.Image.open(
                os.path.join(self.image_base_path, feature["img"])
            ).convert("RGB")
            label = feature["pts"]
            image, x_min, y_min, width = self.cut_face(image, label)
            batch["labels"].append([[x - x_min, y - y_min] for x, y in label])
            batch["x"].append(image)

        # print("This was called")
        batch["labels"] = torch.Tensor(batch["labels"]).to(device) / width * 2 - 1
        batch["x"] = torch.stack(batch["x"]).to(device)
        return batch

    def adjust_bbox(
        self,
        x_min: int,
        y_min: int,
        x_max: int,
        y_max: int,
        image_width: int,
        image_height: int,
        margin_percentage=50,
    ):
        width = x_max - x_min
        height = y_max - y_min

        increase_width = width * (margin_percentage / 100.0) / 2
        increase_height = height * (margin_percentage / 100.0) / 2

        x_min_adjusted = max(0, x_min - increase_width)
        y_min_adjusted = max(0, y_min - increase_height)
        x_max_adjusted = min(image_width, x_max + increase_width)
        y_max_adjusted = min(image_height, y_max + increase_height)

        return x_min_adjusted, y_min_adjusted, x_max_adjusted, y_max_adjusted

    def cut_face(self, img: PIL.Image.Image, pts: list[list[float]]):
        x_vals = [point[0] for point in pts]
        y_vals = [point[1] for point in pts]
        x_min, x_max = int(min(x_vals)), int(max(x_vals))
        y_min, y_max = int(min(y_vals)), int(max(y_vals))
        # Make the image square
        face_img_w, face_img_h = x_max - x_min, y_max - y_min
        side_len = max(face_img_w, face_img_h)
        x_min = max(0, x_min - (side_len - face_img_w) / 2)
        x_max = min(img.width, x_max + (side_len - face_img_w) / 2)
        y_min = max(0, y_min - (side_len - face_img_h) / 2)
        y_max = min(img.height, y_max + (side_len - face_img_h) / 2)

        # Padding
        x_min, y_min, x_max, y_max = self.adjust_bbox(
            x_min, y_min, x_max, y_max, img.width, img.height
        )
        image = img.crop((int(x_min), int(y_min), int(x_max), int(y_max)))
        image: torch.Tensor = self.transforms_image(image)
        return image, x_min, y_min, x_max - x_min


def main():
    dataset = load_dataset(dataset_path="/kaggle/input/300w-with-json/train.json")
    # print(dataset["train"][78])
    # exit(1)
    # model = load_model(weight_path="model.pt")
    model = load_model(weight_path=None)
    trainer = Trainer(
        model,
        args=TrainingArguments(
            output_dir=os.path.join(
                "saves", datetime.strftime(datetime.now(), "%Y%m%d-%H%M")
            ),
            dataloader_pin_memory=False,
            eval_strategy="steps",
            eval_steps=200,
            optim="adamw_torch",
            per_device_train_batch_size=batch_size,
            per_device_eval_batch_size=batch_size,
            gradient_accumulation_steps=gradient_accumulation,
            learning_rate=1e-4,
            save_strategy="steps",
            save_steps=200,
            save_total_limit=3,
            save_safetensors=False,
            remove_unused_columns=False,
            report_to=["tensorboard"],
            # max_steps=200,
            num_train_epochs=12,
            logging_steps=1,
        ),
        train_dataset=dataset["train"],
        eval_dataset=dataset["test"],
        data_collator=DataCollator(image_base_path="/kaggle/input/ibug-300w-large-face-landmark-dataset/ibug_300W_large_face_landmark_dataset"),
    )

    trainer.train()


if __name__ == "__main__":
    main()
# Out:
# Overwriting facial-landmark-localization/Source/train.py

# %%
# !cd facial-landmark-localization/Source && CUDA_VISIBLE_DEVICES=0 python train.py
# Out:
# 2025-05-01 12:56:46.573782: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746104207.046563      66 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746104207.167217      66 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Generating train split: 6666 examples [00:01, 5742.25 examples/s]
# Downloading: "https://download.pytorch.org/models/swin_b-68c6b09e.pth" to /root/.cache/torch/hub/checkpoints/swin_b-68c6b09e.pth
# 100%|█████████████████████████████████████████| 335M/335M [00:01<00:00, 205MB/s]
# {'loss': 3.2881, 'grad_norm': 1.4522455930709839, 'learning_rate': 0.0001, 'epoch': 0.01}
# {'loss': 1.5019, 'grad_norm': 0.48907673358917236, 'learning_rate': 9.992492492492494e-05, 'epoch': 0.02}
# {'loss': 1.4671, 'grad_norm': 0.39369842410087585, 'learning_rate': 9.984984984984985e-05, 'epoch': 0.03}
# {'loss': 6.7298, 'grad_norm': 1.294674038887024, 'learning_rate': 9.977477477477478e-05, 'epoch': 0.04}
#  89%|██████████████████████████████████████▍    | 50/56 [00:41<00:05,  1.11it/s]
#  91%|███████████████████████████████████████▏   | 51/56 [00:42<00:04,  1.09it/s]
#  93%|███████████████████████████████████████▉   | 52/56 [00:43<00:03,  1.18it/s]
#  95%|████████████████████████████████████████▋  | 53/56 [00:44<00:02,  1.09it/s]
#  96%|█████████████████████████████████████████▍ | 54/56 [00:44<00:01,  1.16it/s]
#  98%|██████████████████████████████████████████▏| 55/56 [00:45<00:00,  1.26it/s]
#
# {'eval_loss': 3.7728700637817383, 'eval_runtime': 48.0131, 'eval_samples_per_second': 27.784, 'eval_steps_per_second': 1.166, 'epoch': 1.79}
#  15%|██████                                  | 200/1332 [08:46<37:55,  2.01s/it]
# 100%|███████████████████████████████████████████| 56/56 [00:46<00:00,  1.48it/s]
# {'loss': 0.4877, 'grad_norm': 7.822288990020752, 'learning_rate': 8.4984984984985e-05, 'epoch': 1.8}
# {'loss': 1.1843, 'grad_norm': 9.440254211425781, 'learning_rate': 8.49099099099099e-05, 'epoch': 1.81}
# {'loss': 7.9099, 'grad_norm': 11.90149211883545, 'learning_rate': 8.483483483483484e-05, 'epoch': 1.82}
# {'loss': 0.4567, 'grad_norm': 5.990363121032715, 'learning_rate': 8.475975975975976e-05, 'epoch': 1.83}
# {'loss': 15.2853, 'grad_norm': 61.76213455200195, 'learning_rate': 8.468468468468469e-05, 'epoch': 1.83}
# {'loss': 3.3088, 'grad_norm': 5.557403564453125, 'learning_rate': 8.460960960960962e-05, 'epoch': 1.84}
# {'loss': 0.9791, 'grad_norm': 6.225423812866211, 'learning_rate': 8.453453453453454e-05, 'epoch': 1.85}
# {'loss': 0.5899, 'grad_norm': 3.9794230461120605, 'learning_rate': 8.445945945945946e-05, 'epoch': 1.86}
# {'loss': 2.5426, 'grad_norm': 14.85114860534668, 'learning_rate': 8.438438438438439e-05, 'epoch': 1.87}
# {'loss': 1.6222, 'grad_norm': 8.231783866882324, 'learning_rate': 8.430930930930932e-05, 'epoch': 1.88}
# {'loss': 0.2165, 'grad_norm': 1.854063868522644, 'learning_rate': 8.423423423423423e-05, 'epoch': 1.89}
# {'loss': 0.5973, 'grad_norm': 6.254180908203125, 'learning_rate': 8.415915915915916e-05, 'epoch': 1.9}
# {'loss': 6.3655, 'grad_norm': 30.560462951660156, 'learning_rate': 8.408408408408409e-05, 'epoch': 1.91}
# {'loss': 0.6535, 'grad_norm': 9.758550643920898, 'learning_rate': 8.400900900900901e-05, 'epoch': 1.91}
# {'loss': 0.5302, 'grad_norm': 11.876847267150879, 'learning_rate': 8.393393393393394e-05, 'epoch': 1.92}
# {'loss': 1.1994, 'grad_norm': 2.8372833728790283, 'learning_rate': 8.385885885885885e-05, 'epoch': 1.93}
# {'loss': 1.7804, 'grad_norm': 2.273966073989868, 'learning_rate': 8.378378378378379e-05, 'epoch': 1.94}
# {'loss': 0.5421, 'grad_norm': 5.921701908111572, 'learning_rate': 8.370870870870872e-05, 'epoch': 1.95}
# {'loss': 0.9456, 'grad_norm': 4.903568267822266, 'learning_rate': 8.363363363363363e-05, 'epoch': 1.96}
# {'loss': 0.4587, 'grad_norm': 7.290177822113037, 'learning_rate': 3.003003003003003e-07, 'epoch': 11.87}
# {'loss': 0.8786, 'grad_norm': 16.362707138061523, 'learning_rate': 2.2522522522522524e-07, 'epoch': 11.88}
# {'loss': 1.1775, 'grad_norm': 18.091684341430664, 'learning_rate': 1.5015015015015016e-07, 'epoch': 11.89}
# {'loss': 0.7874, 'grad_norm': 25.625484466552734, 'learning_rate': 7.507507507507508e-08, 'epoch': 11.9}
# {'train_runtime': 3098.0688, 'train_samples_per_second': 20.653, 'train_steps_per_second': 0.43, 'train_loss': 3.5448676428642942, 'epoch': 11.9}
# 100%|███████████████████████████████████████| 1332/1332 [51:38<00:00,  2.33s/it]

# %%
# !huggingface-cli whoami
# Out:
# thng292
# orgs:  venera-ai,pre-view

# %%
# !huggingface-cli upload FaceXFormer-train-test facial-landmark-localization/Source/saves . --private
# Out:
# Consider using `hf_transfer` for faster uploads. This solution comes with some limitations. See https://huggingface.co/docs/huggingface_hub/hf_transfer for more details.
# Start hashing 19 files.
# Finished hashing 19 files.
#
# optimizer.pt:   0%|                                 | 0.00/33.8M [00:00<?, ?B/s]
#
# training_args.bin:   0%|                            | 0.00/5.30k [00:00<?, ?B/s]
#
#
# Upload 10 LFS files:   0%|                               | 0/10 [00:00<?, ?it/s]
#
#
#
# pytorch_model.bin:   0%|                             | 0.00/369M [00:00<?, ?B/s]
#
#
#
#
# optimizer.pt:   0%|                                 | 0.00/33.8M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|                     | 377k/369M [00:00<01:44, 3.53MB/s]
#
#
#
#
# optimizer.pt:   1%|▎                        | 377k/33.8M [00:00<00:09, 3.44MB/s]
#
#
#
# training_args.bin: 100%|███████████████████| 5.30k/5.30k [00:00<00:00, 33.2kB/s]
#
# pytorch_model.bin:   3%|▌                   | 9.80M/369M [00:00<00:06, 55.4MB/s]
#
#
#
#
# optimizer.pt:  25%|██████                  | 8.50M/33.8M [00:00<00:00, 47.4MB/s]
#
#
#
# pytorch_model.bin:   3%|▌                   | 10.2M/369M [00:00<00:06, 56.8MB/s]
# pytorch_model.bin:   4%|▊                   | 16.0M/369M [00:00<00:09, 38.0MB/s]
#
# training_args.bin:   0%|                            | 0.00/5.30k [00:00<?, ?B/s]
#
#
#
# pytorch_model.bin:   4%|▊                   | 16.0M/369M [00:00<00:10, 32.9MB/s]
# training_args.bin: 100%|███████████████████| 5.30k/5.30k [00:00<00:00, 64.1kB/s]
#
#
#
#
# pytorch_model.bin:   8%|█▌                  | 29.0M/369M [00:00<00:05, 58.8MB/s]
#
# optimizer.pt:   0%|                                 | 0.00/33.8M [00:00<?, ?B/s]
# pytorch_model.bin:  10%|█▉                  | 36.5M/369M [00:00<00:07, 45.8MB/s]
#
# optimizer.pt:  16%|███▉                    | 5.51M/33.8M [00:00<00:00, 34.1MB/s]
#
#
#
# pytorch_model.bin:  10%|█▉                  | 36.6M/369M [00:00<00:07, 42.3MB/s]
#
#
#
#
# optimizer.pt:  47%|███████████▎            | 16.0M/33.8M [00:00<00:01, 16.8MB/s]
#
#
#
#
# optimizer.pt:  78%|██████████████████▊     | 26.6M/33.8M [00:01<00:00, 27.8MB/s]
# pytorch_model.bin:  13%|██▌                 | 48.0M/369M [00:01<00:07, 44.9MB/s]
#
#
#
# pytorch_model.bin:  13%|██▌                 | 48.0M/369M [00:01<00:08, 39.3MB/s]
#
#
#
# pytorch_model.bin:  17%|███▎                | 61.8M/369M [00:01<00:05, 56.0MB/s]
# pytorch_model.bin:  17%|███▍                | 64.0M/369M [00:01<00:05, 51.1MB/s]
#
#
#
#
# optimizer.pt:  95%|██████████████████████▋ | 32.0M/33.8M [00:01<00:00, 24.6MB/s]
# pytorch_model.bin:  20%|████                | 75.6M/369M [00:01<00:04, 60.7MB/s]
#
# optimizer.pt:  47%|███████████▎            | 16.0M/33.8M [00:00<00:00, 18.8MB/s]
#
#
#
# optimizer.pt: 100%|████████████████████████| 33.8M/33.8M [00:01<00:00, 21.7MB/s]
#
#
# optimizer.pt:  81%|███████████████████▎    | 27.3M/33.8M [00:00<00:00, 30.2MB/s]
#
#
#
# pytorch_model.bin:  21%|████▏               | 77.9M/369M [00:01<00:05, 51.0MB/s]
#
#
#
#
# pytorch_model.bin:   0%|                             | 0.00/369M [00:00<?, ?B/s]
#
#
#
# pytorch_model.bin:  23%|████▌               | 84.5M/369M [00:01<00:06, 44.8MB/s]
# pytorch_model.bin:  22%|████▍               | 82.7M/369M [00:01<00:08, 34.9MB/s]
#
#
#
# pytorch_model.bin:  25%|█████               | 93.9M/369M [00:01<00:05, 53.8MB/s]
#
# optimizer.pt:  95%|██████████████████████▋ | 32.0M/33.8M [00:01<00:00, 24.1MB/s]
# pytorch_model.bin:  26%|█████▏              | 96.0M/369M [00:02<00:07, 36.7MB/s]
#
#
#
#
# optimizer.pt: 100%|████████████████████████| 33.8M/33.8M [00:01<00:00, 20.0MB/s]
#
#
# training_args.bin:   0%|                            | 0.00/5.30k [00:00<?, ?B/s]
# pytorch_model.bin:  30%|██████▍              | 112M/369M [00:02<00:05, 42.8MB/s]
#
#
#
#
# training_args.bin: 100%|███████████████████| 5.30k/5.30k [00:00<00:00, 73.2kB/s]
#
# pytorch_model.bin:  34%|███████              | 124M/369M [00:02<00:04, 51.5MB/s]
#
#
#
#
# pytorch_model.bin:  12%|██▎                 | 43.5M/369M [00:00<00:05, 54.2MB/s]
#
# events.out.tfevents.1746104234.6cd4d7f05b44.66.0:   0%| | 0.00/287k [00:00<?, ?B
#
#
#
# pytorch_model.bin:  27%|█████▋               | 101M/369M [00:02<00:13, 20.1MB/s]
# events.out.tfevents.1746104234.6cd4d7f05b44.66.0: 100%|█| 287k/287k [00:00<00:00
#
#
#
#
# pytorch_model.bin:  30%|██████▍              | 112M/369M [00:03<00:11, 23.2MB/s]
# pytorch_model.bin:  39%|████████▏            | 144M/369M [00:03<00:05, 39.1MB/s]
#
#
#
#
# pytorch_model.bin:  14%|██▊                 | 51.3M/369M [00:01<00:12, 26.2MB/s]
# pytorch_model.bin:  42%|████████▊            | 154M/369M [00:03<00:04, 45.4MB/s]
#
#
#
# pytorch_model.bin:  35%|███████▎             | 128M/369M [00:03<00:07, 31.3MB/s]
#
#
#
# pytorch_model.bin:  38%|████████             | 141M/369M [00:03<00:05, 41.4MB/s]
#
#
#
#
# pytorch_model.bin:  17%|███▍                | 64.0M/369M [00:01<00:09, 30.9MB/s]
# pytorch_model.bin:  43%|█████████            | 160M/369M [00:03<00:05, 37.1MB/s]
#
#
#
#
# pytorch_model.bin:  22%|████▎               | 80.0M/369M [00:02<00:07, 39.5MB/s]
#
#
#
# pytorch_model.bin:  40%|████████▍            | 148M/369M [00:03<00:05, 37.1MB/s]
# pytorch_model.bin:  48%|██████████           | 176M/369M [00:04<00:04, 41.8MB/s]
#
#
#
#
# pytorch_model.bin:  26%|█████▏              | 96.0M/369M [00:02<00:05, 45.5MB/s]
#
#
#
# pytorch_model.bin:  43%|█████████            | 160M/369M [00:04<00:05, 35.5MB/s]
#
#
#
# pytorch_model.bin:  47%|█████████▊           | 172M/369M [00:04<00:04, 45.2MB/s]
#
#
#
#
# pytorch_model.bin:  30%|██████▍              | 112M/369M [00:02<00:05, 48.5MB/s]
# pytorch_model.bin:  52%|██████████▉          | 192M/369M [00:04<00:04, 37.4MB/s]
#
#
#
# pytorch_model.bin:  48%|██████████▏          | 179M/369M [00:04<00:04, 39.7MB/s]
#
#
#
#
# pytorch_model.bin:  35%|███████▎             | 128M/369M [00:03<00:04, 50.8MB/s]
#
#
#
# pytorch_model.bin:  51%|██████████▊          | 189M/369M [00:04<00:03, 49.5MB/s]
# pytorch_model.bin:  56%|███████████▊         | 208M/369M [00:04<00:03, 43.3MB/s]
#
#
#
# pytorch_model.bin:  53%|███████████▏         | 196M/369M [00:05<00:04, 41.8MB/s]
#
#
#
#
# pytorch_model.bin:  39%|████████▏            | 144M/369M [00:03<00:04, 47.3MB/s]
#
#
#
# pytorch_model.bin:  56%|███████████▊         | 208M/369M [00:05<00:03, 42.7MB/s]
# pytorch_model.bin:  61%|████████████▊        | 224M/369M [00:05<00:03, 40.4MB/s]
#
#
#
# optimizer.pt:  47%|███████████▎            | 16.0M/33.8M [00:05<00:07, 2.52MB/s]
#
#
#
#
# optimizer.pt:  67%|████████████████▏       | 22.8M/33.8M [00:05<00:02, 4.21MB/s]
#
#
#
# pytorch_model.bin:  61%|████████████▉        | 226M/369M [00:05<00:03, 42.3MB/s]
#
#
#
#
# optimizer.pt:  95%|██████████████████████▋ | 32.0M/33.8M [00:05<00:00, 6.90MB/s]
#
#
#
# optimizer.pt: 100%|████████████████████████| 33.8M/33.8M [00:06<00:00, 5.60MB/s]
#
#
#
#
#
# pytorch_model.bin:  52%|██████████▉          | 192M/369M [00:04<00:03, 51.6MB/s]
# pytorch_model.bin:  65%|█████████████▋       | 240M/369M [00:06<00:04, 29.7MB/s]
#
#
# Upload 10 LFS files:  10%|██▎                    | 1/10 [00:06<00:55,  6.18s/it]
#
#
#
# pytorch_model.bin:  69%|██████████████▌      | 256M/369M [00:06<00:02, 49.7MB/s]
#
#
#
#
# pytorch_model.bin:  56%|███████████▊         | 208M/369M [00:04<00:02, 54.2MB/s]
# pytorch_model.bin:  69%|██████████████▌      | 256M/369M [00:06<00:03, 34.5MB/s]
#
#
#
# pytorch_model.bin:  74%|███████████████▍     | 272M/369M [00:06<00:01, 55.5MB/s]
# pytorch_model.bin:  74%|███████████████▍     | 272M/369M [00:06<00:02, 39.6MB/s]
#
#
#
# pytorch_model.bin:  78%|████████████████▍    | 288M/369M [00:06<00:01, 49.1MB/s]
# pytorch_model.bin:  78%|████████████████▍    | 288M/369M [00:06<00:01, 45.2MB/s]
#
#
#
#
# pytorch_model.bin:  61%|████████████▊        | 224M/369M [00:05<00:03, 40.7MB/s]
#
#
#
# pytorch_model.bin:  82%|█████████████████▎   | 304M/369M [00:07<00:01, 53.1MB/s]
# pytorch_model.bin:  82%|█████████████████▎   | 304M/369M [00:07<00:01, 49.2MB/s]
#
#
#
#
# pytorch_model.bin:  65%|█████████████▋       | 240M/369M [00:05<00:02, 43.4MB/s]
#
#
#
# pytorch_model.bin:  87%|██████████████████▏  | 320M/369M [00:07<00:00, 57.3MB/s]
#
#
#
# pytorch_model.bin:  90%|██████████████████▉  | 332M/369M [00:07<00:00, 66.0MB/s]
#
#
#
#
# pytorch_model.bin:  69%|██████████████▌      | 256M/369M [00:05<00:02, 45.8MB/s]
#
#
#
# pytorch_model.bin:  92%|███████████████████▍ | 340M/369M [00:07<00:00, 51.0MB/s]
# pytorch_model.bin:  87%|██████████████████▏  | 320M/369M [00:07<00:01, 37.9MB/s]
#
#
#
# pytorch_model.bin:  96%|████████████████████ | 352M/369M [00:07<00:00, 53.4MB/s]
# pytorch_model.bin:  91%|███████████████████▏ | 336M/369M [00:08<00:00, 42.4MB/s]
#
#
#
#
# pytorch_model.bin:  74%|███████████████▍     | 272M/369M [00:06<00:02, 37.8MB/s]
#
#
#
# pytorch_model.bin: 100%|█████████████████████| 369M/369M [00:08<00:00, 43.8MB/s]
#
#
#
#
#
# pytorch_model.bin:  78%|████████████████▍    | 288M/369M [00:06<00:01, 40.8MB/s]
# pytorch_model.bin:  96%|████████████████████ | 352M/369M [00:08<00:00, 37.7MB/s]
#
#
#
#
# pytorch_model.bin:  82%|█████████████████▎   | 304M/369M [00:07<00:01, 43.8MB/s]
# pytorch_model.bin: 100%|████████████████████▉| 368M/369M [00:08<00:00, 41.1MB/s]
#
#
#
#
# pytorch_model.bin: 100%|█████████████████████| 369M/369M [00:09<00:00, 40.4MB/s]
#
#
#
#
#
# pytorch_model.bin:  91%|███████████████████▏ | 336M/369M [00:07<00:00, 52.3MB/s]
#
#
# Upload 10 LFS files:  20%|████▌                  | 2/10 [00:09<00:35,  4.39s/it]
#
#
#
#
# pytorch_model.bin:  96%|████████████████████ | 352M/369M [00:07<00:00, 54.6MB/s]
#
#
#
#
# pytorch_model.bin: 100%|█████████████████████| 369M/369M [00:08<00:00, 44.3MB/s]
#
#
#
# Upload 10 LFS files: 100%|██████████████████████| 10/10 [00:10<00:00,  1.05s/it]
# https://huggingface.co/thng292/FaceXFormer-train-test/tree/main/.
